# %%
import pandas as pd
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lag_df = pd.read_csv('Lagos_Branch.csv')
abj_df = pd.read_csv('Abuja_Branch.csv')
ph_df = pd.read_csv('Port_Harcourt_Branch.csv')

# %%
lag_df.head(10)
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  750-67-8428      A  Lagos        Member  Female       Health and beauty
# 1  631-41-3108      A  Lagos        Normal    Male      Home and lifestyle
# 2  123-19-1176      A  Lagos        Member    Male       Health and beauty
# 3  373-73-7910      A  Lagos        Normal    Male       Sports and travel
# 4  355-53-5943      A  Lagos        Member  Female  Electronic accessories
# 5  665-32-9167      A  Lagos        Member  Female       Health and beauty
# 6  365-64-0515      A  Lagos        Normal  Female  Electronic accessories
# 7  252-56-2699      A  Lagos        Normal    Male      Food and beverages
# 8  829-34-3910      A  Lagos        Normal  Female       Health and beauty
# 9  656-95-9349      A  Lagos        Member  Female       Health and beauty
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# ...

# %%
abj_df.head(10)
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
# 5  371-85-5789      B  Abuja        Normal    Male       Health and beauty
# 6  273-16-6619      B  Abuja        Normal    Male      Home and lifestyle
# 7  649-29-6775      B  Abuja        Normal    Male     Fashion accessories
# 8  145-94-9061      B  Abuja        Normal  Female      Food and beverages
# 9  871-79-8483      B  Abuja        Normal    Male     Fashion accessories
#
#    Unit price  Quantity    Tax 5%      Total        Date   Time Payment  \
# ...

# %%
ph_df.head(10)
# Out:
#     Invoice ID Branch           City Customer type  Gender  \
# 0  226-31-3081      C  Port Harcourt        Normal  Female
# 1  699-14-3026      C  Port Harcourt        Normal    Male
# 2  315-22-5665      C  Port Harcourt        Normal  Female
# 3  300-71-4605      C  Port Harcourt        Member    Male
# 4  183-56-6882      C  Port Harcourt        Member  Female
# 5  232-16-2483      C  Port Harcourt        Member  Female
# 6  333-73-7901      C  Port Harcourt        Normal  Female
# 7  554-53-8700      C  Port Harcourt        Member    Male
# 8  228-96-1411      C  Port Harcourt        Member  Female
# 9  617-15-4209      C  Port Harcourt        Member    Male
#
#              Product line  Unit price  Quantity    Tax 5%      Total  \
# 0  Electronic accessories      5500.8         5   1375.20   28879.20
# 1  Electronic accessories     30740.4         7  10759.14  225941.94
# 2      Home and lifestyle     26481.6        10  13240.80  278056.80
# ...

# %%
all_stores_df = pd.concat([lag_df, abj_df, ph_df], sort=False)

# %%
all_stores_df
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    750-67-8428      A          Lagos        Member  Female
# 1    631-41-3108      A          Lagos        Normal    Male
# 2    123-19-1176      A          Lagos        Member    Male
# 3    373-73-7910      A          Lagos        Normal    Male
# 4    355-53-5943      A          Lagos        Member  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Health and beauty     26888.4         7   9410.94  197629.74
# 1        Home and lifestyle     16678.8         7   5837.58  122589.18
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

plt.figure(figsize = (16,5))


from matplotlib import rcParams

rcParams['figure.figsize'] = 14.7, 8.27

# %%
all_stores_df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  750-67-8428      A  Lagos        Member  Female       Health and beauty
# 1  631-41-3108      A  Lagos        Normal    Male      Home and lifestyle
# 2  123-19-1176      A  Lagos        Member    Male       Health and beauty
# 3  373-73-7910      A  Lagos        Normal    Male       Sports and travel
# 4  355-53-5943      A  Lagos        Member  Female  Electronic accessories
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     26888.4         7   9410.94  197629.74   1/5/2019  13:08    Epay
# 1     16678.8         7   5837.58  122589.18   3/3/2019  13:23    Card
# 2     20959.2         8   8383.68  176057.28  1/27/2019  20:33    Epay
# 3     31071.6         7  10875.06  228376.26   2/8/2019  10:37    Epay
# 4     24782.4         6   7434.72  156129.12  2/25/2019  14:36    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
all_stores_df.shape
# Out:
# (1000, 17)

# %%
all_stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 327
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
all_stores_df['Date'] = pd.to_datetime(all_stores_df['Date'])
all_stores_df['Time'] = pd.to_datetime(all_stores_df['Time'])

# %%
all_stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 327
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %%
all_stores_df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
all_stores_df.duplicated().sum()
# Out:
# 0

# %%
all_stores_df.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# ...

# %%
all_stores_df['Year'] = all_stores_df['Date'].dt.year
all_stores_df['Month'] = all_stores_df['Date'].dt.year
all_stores_df['Day'] = all_stores_df['Date'].dt.year
all_stores_df['Hour'] = all_stores_df['Time'].dt.year

# %%
all_stores_df
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    750-67-8428      A          Lagos        Member  Female
# 1    631-41-3108      A          Lagos        Normal    Male
# 2    123-19-1176      A          Lagos        Member    Male
# 3    373-73-7910      A          Lagos        Normal    Male
# 4    355-53-5943      A          Lagos        Member  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  ...  \
# 0         Health and beauty     26888.4         7   9410.94  197629.74  ...
# 1        Home and lifestyle     16678.8         7   5837.58  122589.18  ...
# ...

# %%
all_stores_df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
all_stores_df['Payment'].value_counts()
# Out:
# Epay    345
# Cash    344
# Card    311
# Name: Payment, dtype: int64

# %%
all_stores_df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
sns.countplot(x='Product line', data = all_stores_df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
all_stores_df['Year'].unique()
# Out:
# array([2019], dtype=int64)

# %%
all_stores_df['Month'].unique()
# Out:
# array([2019], dtype=int64)

# %%
all_stores_df['Total'].describe()
# Out:
# count      1000.000000
# mean     116268.029640
# std       88518.720636
# min        3844.260000
# 25%       44792.055000
# 50%       91385.280000
# 75%      169686.090000
# max      375354.000000
# Name: Total, dtype: float64

# %%
all_stores_df['Total'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
all_stores_df['Unit price'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
all_stores_df.groupby(by='City').sum()['Total']
# Out:
# City
# Abuja            38231161.92
# Lagos            38232133.38
# Port Harcourt    39804734.34
# Name: Total, dtype: float64

# %%
all_stores_df.groupby(by='City').sum()[['Total']]
# Out:
#                      Total
# City
# Abuja          38231161.92
# Lagos          38232133.38
# Port Harcourt  39804734.34

# %%
all_stores_df.groupby(by='Product line',sort=False).sum()[['Total']]
# Out:
#                               Total
# Product line
# Health and beauty       17709746.04
# Home and lifestyle      19390288.68
# Sports and travel       19844217.54
# Electronic accessories  19561511.34
# Food and beverages      20212143.84
# Fashion accessories     19550122.20

# %%
sns.countplot(x= 'Product line', data = all_stores_df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
sns.countplot(x= 'Payment', data = all_stores_df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x='Gender', data = all_stores_df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.barplot(x='City',y='Total',data=all_stores_df).set_title('Branch with the highest total sale')
# Out:
# Text(0.5, 1.0, 'Branch with the highest total sale')

# %%
sns.barplot(x='Product line',y='Total', data=all_stores_df, hue='City').set_title('Product line with the the highest sales by branch')
# Out:
# Text(0.5, 1.0, 'Product line with the the highest sales by branch')

# %%
sns.barplot(x='City', y='Rating', data=all_stores_df).set_title('Cities with highest ratings')
# Out:
# Text(0.5, 1.0, 'Cities with highest ratings')

# %%
sns.boxplot(x='Branch', y='Total', data= all_stores_df).set_title('Spreads of the total sales by branch')
# Out:
# Text(0.5, 1.0, 'Spreads of the total sales by branch')

# %%
sns.barplot(x='Gender', y='Total', data=all_stores_df, hue='Product line', ci=0).set_title('Total sales by Gender filtered by Product line')
# Out:
# Text(0.5, 1.0, 'Total sales by Gender filtered by Product line')

# %%
sns.barplot(x='Gender', y= 'Total', data=all_stores_df)
